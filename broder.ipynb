# %%
import snap
import random
import bfs_json
reload(bfs_json)
# Out:
# <module 'bfs_json' from 'bfs_json.py'>

# %%
bfs_json.get_bfs_graph(0, 2, True, False)
# Out:
# {u'followedInLinks': False,
#  u'followedOutLinks': True,
#  u'numFoundEdges': 0,
#  u'numFoundNodes': 1,
#  u'numberBFSLevels': 2,
#  u'outputEdgeList': u'0.txt',
#  u'sourcePaperID': 0}

# %%
reload(bfs_json)
bfs_json.get_random_nodes()
# Out:
# gshuf -n 1000 PaperReferences.txt
# sh
# pcputimes(user=0.002270689, system=0.006024568, children_user=0.0, children_system=0.0)
# pmem(rss=684032L, vms=4372094976L, pfaults=958, pageins=11)
# 40407
# running
# gshuf
# pcputimes(user=0.408013376, system=0.380202304, children_user=0.0, children_system=0.0)
# pmem(rss=1204224L, vms=4390408192L, pfaults=1383, pageins=12)
# 40407
# running
# gshuf
# pcputimes(user=0.82525056, system=0.744330688, children_user=0.0, children_system=0.0)
# pmem(rss=1204224L, vms=4390408192L, pfaults=1383, pageins=12)
# 40407
# running
# gshuf
# pcputimes(user=1.248708224, system=1.11080064, children_user=0.0, children_system=0.0)
# pmem(rss=1204224L, vms=4390408192L, pfaults=1383, pageins=12)
# 40407
# running
# gshuf
# pcputimes(user=1.661350784, system=1.477430656, children_user=0.0, children_system=0.0)
# pmem(rss=1204224L, vms=4390408192L, pfaults=1383, pageins=12)
# 40407
# running
# gshuf
# ...
